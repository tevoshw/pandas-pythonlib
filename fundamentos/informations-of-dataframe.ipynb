# %% [markdown]
# #  HOW TO SEE THE INFORMATIONS OF A DATAFRAME/SET/BASE

# %%
import pandas as pd

df = pd.read_csv('../datasets/GasPricesinBrazil_2004-2019.csv', sep = ';')
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# #### DF.INFO() : SHOW ALL THE INFORMATIONS OF, FEATURES AND ROWS, DTYPE AND MORE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# ##### DF.SHAPE : SHOW THE ROWS X FEATURES

# %%
len(df) # SHOW THE TOTAL OF INDEXS/SAMPLES
# Out:
# 106823

# %%
df.shape # IT'S NOT A FUNCTION, WE DONT USE LIKE df.shape()
# ROWS , FEATURES
# Out:
# (106823, 21)

# %%
df.shape[0]
# Out:
# 106823

# %%
df.shape[1]
# Out:
# 21

# %% [markdown]
# ##### DF.COLUMNS : SHOW ALL THE FEATURES WITH THE NAME E SEUS DTYPE

# %%
df.columns #  not use like a function, goes error
# Out:
# Index(['Unnamed: 0', 'DATA INICIAL', 'DATA FINAL', 'REGIÃO', 'ESTADO',
#        'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
#        'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
#        'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
#        'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
#        'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
#        'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO', 'MÊS',
#        'ANO'],
#       dtype='object')

# %% [markdown]
# #### DF.TYPES : SHOW ALL THE FEATURES WITH THE DTYPE

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# DATA INICIAL                      object
# DATA FINAL                        object
# REGIÃO                            object
# ESTADO                            object
# PRODUTO                           object
# NÚMERO DE POSTOS PESQUISADOS       int64
# UNIDADE DE MEDIDA                 object
# PREÇO MÉDIO REVENDA              float64
# DESVIO PADRÃO REVENDA            float64
# PREÇO MÍNIMO REVENDA             float64
# PREÇO MÁXIMO REVENDA             float64
# MARGEM MÉDIA REVENDA              object
# COEF DE VARIAÇÃO REVENDA         float64
# PREÇO MÉDIO DISTRIBUIÇÃO          object
# DESVIO PADRÃO DISTRIBUIÇÃO        object
# PREÇO MÍNIMO DISTRIBUIÇÃO         object
# PREÇO MÁXIMO DISTRIBUIÇÃO         object
# COEF DE VARIAÇÃO DISTRIBUIÇÃO     object
# MÊS                                int64
# ANO                                int64
# dtype: object

# %% [markdown]
# #### DF.DESCRIBE() : SHOW ALL THE FEATURES WITH THEIR STATISTICS

# %%
df.describe()
# Out:
#          Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count  106823.00000                 106823.000000        106823.000000
# mean    53411.00000                    233.770976            10.870780
# std     30837.28824                    403.282519            17.752533
# min         0.00000                      1.000000             0.766000
# 25%     26705.50000                     42.000000             2.072000
# 50%     53411.00000                    104.000000             2.718000
# 75%     80116.50000                    243.000000             3.752000
# max    106822.00000                   4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          106823.000000         106823.000000         106823.000000
# mean                0.657227              9.416038             12.537731
# std                 1.349169             15.092193             20.841497
# ...

# %% [markdown]
# #### DF.TAIL() SHOW TO US THE LAST SAMPLES

# %%
df.tail()
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 106818      106818   2019-06-23  2019-06-29  NORDESTE  RIO GRANDE DO NORTE
# 106819      106819   2019-06-23  2019-06-29       SUL    RIO GRANDE DO SUL
# 106820      106820   2019-06-23  2019-06-29       SUL       SANTA CATARINA
# 106821      106821   2019-06-23  2019-06-29   SUDESTE            SAO PAULO
# 106822      106822   2019-06-23  2019-06-29  NORDESTE              SERGIPE
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 106818     GNV                             7             R$/m3
# 106819     GNV                            23             R$/m3
# 106820     GNV                            24             R$/m3
# 106821     GNV                            52             R$/m3
# 106822     GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...
